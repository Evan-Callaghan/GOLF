# %%
## Importing libraries

import pandas as pd
import numpy as np
import sys; sys.path.insert(1, '/Users/EvanCallaghan/Documents/Golf/StrokesGained/GOLF/GlobalScripts')
pd.set_option('display.max_rows', None, 'display.max_columns', None)
import sg_script as sg
import sg_script_editor as sg_editor

# %%
## Reading the data

baselines = pd.read_excel('/Users/EvanCallaghan/Documents/Golf/StrokesGained/Database/Baselines.xlsx')
courses = pd.read_excel('/Users/EvanCallaghan/Documents/Golf/StrokesGained/Database/Courses.xlsx')
golfers = pd.read_excel('/Users/EvanCallaghan/Documents/Golf/StrokesGained/Database/Golfers.xlsx')
rounds = pd.read_excel('/Users/EvanCallaghan/Documents/Golf/StrokesGained/Database/Rounds.xlsx')
shots = pd.read_excel('/Users/EvanCallaghan/Documents/Golf/StrokesGained/Database/Shots.xlsx')

# %%
## Subsetting the data for the correct golfer and round

## Golfer
golfer = golfers[golfers['Name'] == 'Ben Cameron'].reset_index(drop = True)

## Rounds
rounds = rounds[rounds['roundID'] == 1037].reset_index(drop = True)

## Shots
shot = shots[shots['roundID'] == 1037].reset_index(drop = True)

## Course
courses = courses[(courses['courseID'] == rounds.at[0, 'courseID']) & (courses['Tees'] == rounds.at[0, 'Tees'])].reset_index(drop = True)

# %%
shot
# Out:
#      shotID  roundID  holeNumber  shotNumber  nextLocation  \
# 0   1002744     1037           1           1         149.0
# 1   1002745     1037           1           2          18.0
# 2   1002746     1037           1           3           5.0
# 3   1002747     1037           1           4           0.0
# 4   1002748     1037           2           1         141.0
# 5   1002749     1037           2           2          10.0
# 6   1002750     1037           2           3           2.0
# 7   1002751     1037           2           4           0.0
# 8   1002752     1037           3           1         107.0
# 9   1002753     1037           3           2           7.0
# 10  1002754     1037           3           3           1.0
# 11  1002755     1037           3           4           0.0
# 12  1002756     1037           4           1         226.0
# 13  1002757     1037           4           2          31.0
# 14  1002758     1037           4           3           5.0
# 15  1002759     1037           4           4           1.0
# 16  1002760     1037           4           5           0.0
# 17  1002761     1037           5           1           1.0
# 18  1002762     1037           5           2           0.0
# 19  1002763     1037           6           1         108.0
# 20  1002764     1037           6           2           5.0
# 21  1002765     1037           6           3           1.0
# 22  1002766     1037           6           4           0.0
# 23  1002767     1037           7           1         248.0
# 24  1002768     1037           7           2         164.0
# 25  1002769     1037           7           3          10.0
# 26  1002770     1037           7           4           3.0
# 27  1002771     1037           7           5           1.0
# 28  1002772     1037           7           6           0.0
# 29  1002773     1037           8           1          15.0
# 30  1002774     1037           8           2           5.0
# 31  1002775     1037           8           3           0.0
# 32  1002776     1037           9           1          99.0
# 33  1002777     1037           9           2           5.0
# 34  1002778     1037           9           3           2.0
# 35  1002779     1037           9           4           0.0
# 36  1002780     1037          10           1          11.0
# 37  1002781     1037          10           2           2.0
# 38  1002782     1037          10           3           1.0
# 39  1002783     1037          10           4           0.0
# 40  1002784     1037          11           1         105.0
# 41  1002785     1037          11           2          12.0
# 42  1002786     1037          11           3           4.0
# 43  1002787     1037          11           4           1.0
# 44  1002788     1037          11           5           0.0
# 45  1002789     1037          12           1         119.0
# 46  1002790     1037          12           2          14.0
# 47  1002791     1037          12           3           4.0
# 48  1002792     1037          12           4           1.0
# 49  1002793     1037          12           5           0.0
# 50  1002794     1037          13           1          54.0
# 51  1002795     1037          13           2          10.0
# 52  1002796     1037          13           3           8.0
# 53  1002797     1037          13           4           1.0
# 54  1002798     1037          13           5           0.0
# 55  1002799     1037          14           1          13.0
# 56  1002800     1037          14           2           3.0
# 57  1002801     1037          14           3           0.0
# 58  1002802     1037          15           1          17.0
# 59  1002803     1037          15           2           5.0
# 60  1002804     1037          15           3           1.0
# 61  1002805     1037          15           4           0.0
# 62  1002806     1037          16           1         161.0
# 63  1002807     1037          16           2          14.0
# 64  1002808     1037          16           3           1.0
# 65  1002809     1037          16           4           0.0
# 66  1002810     1037          17           1         174.0
# 67  1002811     1037          17           2           8.0
# 68  1002812     1037          17           3           7.0
# 69  1002813     1037          17           4           2.0
# 70  1002814     1037          17           5           0.0
# 71  1002815     1037          18           1         140.0
# 72  1002816     1037          18           2          15.0
# 73  1002817     1037          18           3           1.0
# 74  1002818     1037          18           4           0.0
#
#    nextLocationLieType penaltyIncurred teeShotMiss  recoveryShot
# 0                Rough             NaN       Right           NaN
# 1                Rough             NaN         NaN           NaN
# 2                Green             NaN         NaN           NaN
# 3                 Hole             NaN         NaN           NaN
# 4              Fairway             NaN         NaN           NaN
# 5                 Sand             NaN         NaN           NaN
# 6                Green             NaN         NaN           NaN
# 7                 Hole             NaN         NaN           NaN
# 8              Fairway             NaN         NaN           NaN
# 9                Green             NaN         NaN           NaN
# 10               Green             NaN         NaN           NaN
# 11                Hole             NaN         NaN           NaN
# 12               Rough             NaN       Right           NaN
# 13             Fairway             NaN         NaN           NaN
# 14               Green             NaN         NaN           NaN
# 15               Green             NaN         NaN           NaN
# 16                Hole             NaN         NaN           NaN
# 17               Green             NaN         NaN           NaN
# 18                Hole             NaN         NaN           NaN
# 19             Fairway             NaN         NaN           NaN
# 20               Green             NaN         NaN           NaN
# 21               Green             NaN         NaN           NaN
# 22                Hole             NaN         NaN           NaN
# 23               Rough             NaN        Left           NaN
# 24               Rough             NaN         NaN           NaN
# 25               Rough             NaN         NaN           NaN
# 26               Green             NaN         NaN           NaN
# 27               Green             NaN         NaN           NaN
# 28                Hole             NaN         NaN           NaN
# 29             Fairway             NaN         NaN           NaN
# 30               Green             NaN         NaN           NaN
# 31                Hole             NaN         NaN           NaN
# 32             Fairway             NaN         NaN           NaN
# 33               Green             NaN         NaN           NaN
# 34               Green             NaN         NaN           NaN
# 35                Hole             NaN         NaN           NaN
# 36               Green             NaN         NaN           NaN
# 37               Green             NaN         NaN           NaN
# 38               Green             NaN         NaN           NaN
# 39                Hole             NaN         NaN           NaN
# 40               Rough             NaN        Left           NaN
# 41               Rough             NaN         NaN           NaN
# 42               Green             NaN         NaN           NaN
# 43               Green             NaN         NaN           NaN
# 44                Hole             NaN         NaN           NaN
# 45               Rough             NaN       Right           NaN
# 46               Rough             NaN         NaN           1.0
# 47               Green             NaN         NaN           NaN
# 48               Green             NaN         NaN           NaN
# 49                Hole             NaN         NaN           NaN
# 50               Rough             NaN       Right           NaN
# 51               Rough             NaN         NaN           NaN
# 52               Rough             NaN         NaN           NaN
# 53               Green             NaN         NaN           NaN
# 54                Hole             NaN         NaN           NaN
# 55             Fairway             NaN         NaN           NaN
# 56               Green             NaN         NaN           NaN
# 57                Hole             NaN         NaN           NaN
# 58                Sand             NaN         NaN           NaN
# 59               Green             NaN         NaN           NaN
# 60               Green             NaN         NaN           NaN
# 61                Hole             NaN         NaN           NaN
# 62             Fairway             NaN         NaN           NaN
# 63               Green             NaN         NaN           NaN
# 64               Green             NaN         NaN           NaN
# 65                Hole             NaN         NaN           NaN
# 66             Fairway             NaN         NaN           NaN
# 67               Rough             NaN         NaN           NaN
# 68               Rough             NaN         NaN           NaN
# 69               Green             NaN         NaN           NaN
# 70                Hole             NaN         NaN           NaN
# 71             Fairway             NaN         NaN           NaN
# 72               Green             NaN         NaN           NaN
# 73               Green             NaN         NaN           NaN
# 74                Hole             NaN         NaN           NaN

# %%
## Creating complete data-frame for analysis

shotLevel, roundLevel = sg_editor.initialize(shot, rounds, courses, baselines)

# %%
## Exporting data-frames for analysis:

shotLevel.to_csv('/Users/EvanCallaghan/Documents/Golf/StrokesGained/Reporting/shotLevel.csv', index = False)
roundLevel.to_csv('/Users/EvanCallaghan/Documents/Golf/StrokesGained/Reporting/roundLevel.csv', index = False)
courses.to_csv('/Users/EvanCallaghan/Documents/Golf/StrokesGained/Reporting/courseLevel.csv', index = False)
